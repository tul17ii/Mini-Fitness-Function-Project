# %% [markdown]
# <a href="https://colab.research.google.com/github/tul17ii/Mini-Fitness-Function-Project/blob/main/ff_with_temperature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

# Step 1: Fitness functions remain unchanged
def crop_yield_fitness(chromosome):
    return random.uniform(0, 100)

def environmental_impact_fitness(chromosome):
    return random.uniform(0, 50)

def combined_fitness(chromosome):
    return crop_yield_fitness(chromosome) - environmental_impact_fitness(chromosome)

# Step 2: Generate random chromosome
def generate_random_chromosome():
    return [
        random.choice(crop_types),
        random.choice(planting_times),
        random.choice(fertilizers),
        random.choice(pesticides),
        random.choice(soil_nutrients),
        random.choice(farm_sizes),
        random.choice(farm_types),
    ]

# Step 3: Mutation for neighborhood exploration
def mutate(chromosome):
    mutation_point = random.randint(0, len(chromosome) - 1)
    if mutation_point == 0:
        chromosome[mutation_point] = random.choice(crop_types)
    elif mutation_point == 1:
        chromosome[mutation_point] = random.choice(planting_times)
    elif mutation_point == 2:
        chromosome[mutation_point] = random.choice(fertilizers)
    elif mutation_point == 3:
        chromosome[mutation_point] = random.choice(pesticides)
    elif mutation_point == 4:
        chromosome[mutation_point] = random.choice(soil_nutrients)
    elif mutation_point == 5:
        chromosome[mutation_point] = random.choice(farm_sizes)
    elif mutation_point == 6:
        chromosome[mutation_point] = random.choice(farm_types)
    return chromosome

# Step 4: Simulated Annealing Algorithm
def simulated_annealing(fitness_function, initial_temp=1000, cooling_rate=0.95, max_iter=1000):
    current_solution = generate_random_chromosome()
    current_fitness = fitness_function(current_solution)
    best_solution = current_solution
    best_fitness = current_fitness
    temperature = initial_temp

    for iteration in range(max_iter):
        # Generate a new solution by mutating the current solution
        new_solution = mutate(current_solution[:])  # Copy the list to avoid modifying current_solution
        new_fitness = fitness_function(new_solution)

        # Accept the new solution based on probability
        if new_fitness > current_fitness or random.random() < math.exp((new_fitness - current_fitness) / temperature):
            current_solution = new_solution
            current_fitness = new_fitness

        # Update the best solution found so far
        if new_fitness > best_fitness:
            best_solution = new_solution
            best_fitness = new_fitness

        # Cool down the temperature
        temperature *= cooling_rate

        # Optional: Print progress
        print(f"Iteration {iteration + 1}: Best Fitness = {best_fitness:.2f}, Temperature = {temperature:.2f}")

        # Stop if temperature is very low
        if temperature < 1e-5:
            break

    return best_solution, best_fitness

# Example usage
crop_types = ["Wheat", "Corn", "Rice", "Soybean"]
planting_times = ["Spring", "Summer", "Fall", "Winter"]
fertilizers = ["Nitrogen", "Phosphorus", "Potassium", "Organic"]
pesticides = ["Herbicide", "Insecticide", "Fungicide", "None"]
soil_nutrients = ["Low", "Medium", "High"]
farm_sizes = ["Small", "Medium", "Large"]
farm_types = ["Organic", "Conventional"]

print("Hello!!! Intelligent Smart Farm Optimization System!")
print("\nChoose a fitness function to optimize:")
print("1. Maximize crop yield")
print("2. Minimize environmental impact")
print("3. Combined optimization (yield and impact)")
choice = input("Enter 1, 2, or 3: ")

if choice == "1":
    fitness_function = crop_yield_fitness
elif choice == "2":
    fitness_function = environmental_impact_fitness
elif choice == "3":
    fitness_function = combined_fitness
else:
    print("Invalid choice. Defaulting to combined optimization.")
    fitness_function = combined_fitness

# Run Simulated Annealing
best_solution, best_fitness = simulated_annealing(fitness_function)
print(f"\nBest solution using Simulated Annealing: {best_solution} with Fitness: {best_fitness:.2f}")
# Out:
# Hello!!! Intelligent Smart Farm Optimization System!
#
# Choose a fitness function to optimize:
# 1. Maximize crop yield
# 2. Minimize environmental impact
# 3. Combined optimization (yield and impact)
# Enter 1, 2, or 3: 3
# Iteration 1: Best Fitness = 61.09, Temperature = 950.00
# Iteration 2: Best Fitness = 61.09, Temperature = 902.50
# Iteration 3: Best Fitness = 61.09, Temperature = 857.38
# Iteration 4: Best Fitness = 99.20, Temperature = 814.51
# Iteration 5: Best Fitness = 99.20, Temperature = 773.78
# Iteration 6: Best Fitness = 99.20, Temperature = 735.09
# Iteration 7: Best Fitness = 99.20, Temperature = 698.34
# Iteration 8: Best Fitness = 99.20, Temperature = 663.42
# Iteration 9: Best Fitness = 99.20, Temperature = 630.25
# Iteration 10: Best Fitness = 99.20, Temperature = 598.74
# Iteration 11: Best Fitness = 99.20, Temperature = 568.80
# Iteration 12: Best Fitness = 99.20, Temperature = 540.36
# Iteration 13: Best Fitness = 99.20, Temperature = 513.34
# Iteration 14: Best Fitness = 99.20, Temperature = 487.67
# Iteration 15: Best Fitness = 99.20, Temperature = 463.29
# Iteration 16: Best Fitness = 99.20, Temperature = 440.13
# Iteration 17: Best Fitness = 99.20, Temperature = 418.12
# Iteration 18: Best Fitness = 99.20, Temperature = 397.21
# Iteration 19: Best Fitness = 99.20, Temperature = 377.35
# Iteration 20: Best Fitness = 99.20, Temperature = 358.49
# Iteration 21: Best Fitness = 99.20, Temperature = 340.56
# Iteration 22: Best Fitness = 99.20, Temperature = 323.53
# Iteration 23: Best Fitness = 99.20, Temperature = 307.36
# Iteration 24: Best Fitness = 99.20, Temperature = 291.99
# Iteration 25: Best Fitness = 99.20, Temperature = 277.39
# Iteration 26: Best Fitness = 99.20, Temperature = 263.52
# Iteration 27: Best Fitness = 99.20, Temperature = 250.34
# Iteration 28: Best Fitness = 99.20, Temperature = 237.83
# Iteration 29: Best Fitness = 99.20, Temperature = 225.94
# Iteration 30: Best Fitness = 99.20, Temperature = 214.64
# Iteration 31: Best Fitness = 99.20, Temperature = 203.91
# Iteration 32: Best Fitness = 99.20, Temperature = 193.71
# Iteration 33: Best Fitness = 99.20, Temperature = 184.03
# Iteration 34: Best Fitness = 99.20, Temperature = 174.82
# Iteration 35: Best Fitness = 99.20, Temperature = 166.08
# Iteration 36: Best Fitness = 99.20, Temperature = 157.78
# Iteration 37: Best Fitness = 99.20, Temperature = 149.89
# Iteration 38: Best Fitness = 99.20, Temperature = 142.40
# Iteration 39: Best Fitness = 99.20, Temperature = 135.28
# Iteration 40: Best Fitness = 99.20, Temperature = 128.51
# Iteration 41: Best Fitness = 99.20, Temperature = 122.09
# Iteration 42: Best Fitness = 99.20, Temperature = 115.98
# Iteration 43: Best Fitness = 99.20, Temperature = 110.18
# Iteration 44: Best Fitness = 99.20, Temperature = 104.67
# Iteration 45: Best Fitness = 99.20, Temperature = 99.44
# Iteration 46: Best Fitness = 99.20, Temperature = 94.47
# Iteration 47: Best Fitness = 99.20, Temperature = 89.74
# Iteration 48: Best Fitness = 99.20, Temperature = 85.26
# Iteration 49: Best Fitness = 99.20, Temperature = 80.99
# Iteration 50: Best Fitness = 99.20, Temperature = 76.94
# Iteration 51: Best Fitness = 99.20, Temperature = 73.10
# Iteration 52: Best Fitness = 99.20, Temperature = 69.44
# Iteration 53: Best Fitness = 99.20, Temperature = 65.97
# Iteration 54: Best Fitness = 99.20, Temperature = 62.67
# Iteration 55: Best Fitness = 99.20, Temperature = 59.54
# Iteration 56: Best Fitness = 99.20, Temperature = 56.56
# Iteration 57: Best Fitness = 99.20, Temperature = 53.73
# Iteration 58: Best Fitness = 99.20, Temperature = 51.05
# Iteration 59: Best Fitness = 99.20, Temperature = 48.49
# Iteration 60: Best Fitness = 99.20, Temperature = 46.07
# Iteration 61: Best Fitness = 99.20, Temperature = 43.77
# Iteration 62: Best Fitness = 99.20, Temperature = 41.58
# Iteration 63: Best Fitness = 99.20, Temperature = 39.50
# Iteration 64: Best Fitness = 99.20, Temperature = 37.52
# Iteration 65: Best Fitness = 99.20, Temperature = 35.65
# Iteration 66: Best Fitness = 99.20, Temperature = 33.87
# Iteration 67: Best Fitness = 99.20, Temperature = 32.17
# Iteration 68: Best Fitness = 99.20, Temperature = 30.56
# Iteration 69: Best Fitness = 99.20, Temperature = 29.04
# Iteration 70: Best Fitness = 99.20, Temperature = 27.58
# Iteration 71: Best Fitness = 99.20, Temperature = 26.20
# Iteration 72: Best Fitness = 99.20, Temperature = 24.89
# Iteration 73: Best Fitness = 99.20, Temperature = 23.65
# Iteration 74: Best Fitness = 99.20, Temperature = 22.47
# Iteration 75: Best Fitness = 99.20, Temperature = 21.34
# Iteration 76: Best Fitness = 99.20, Temperature = 20.28
# Iteration 77: Best Fitness = 99.20, Temperature = 19.26
# Iteration 78: Best Fitness = 99.20, Temperature = 18.30
# Iteration 79: Best Fitness = 99.20, Temperature = 17.38
# Iteration 80: Best Fitness = 99.20, Temperature = 16.52
# Iteration 81: Best Fitness = 99.20, Temperature = 15.69
# Iteration 82: Best Fitness = 99.20, Temperature = 14.91
# Iteration 83: Best Fitness = 99.20, Temperature = 14.16
# Iteration 84: Best Fitness = 99.20, Temperature = 13.45
# Iteration 85: Best Fitness = 99.20, Temperature = 12.78
# Iteration 86: Best Fitness = 99.20, Temperature = 12.14
# Iteration 87: Best Fitness = 99.20, Temperature = 11.53
# Iteration 88: Best Fitness = 99.20, Temperature = 10.96
# Iteration 89: Best Fitness = 99.20, Temperature = 10.41
# Iteration 90: Best Fitness = 99.20, Temperature = 9.89
# Iteration 91: Best Fitness = 99.20, Temperature = 9.39
# Iteration 92: Best Fitness = 99.20, Temperature = 8.92
# Iteration 93: Best Fitness = 99.20, Temperature = 8.48
# Iteration 94: Best Fitness = 99.20, Temperature = 8.05
# Iteration 95: Best Fitness = 99.20, Temperature = 7.65
# Iteration 96: Best Fitness = 99.20, Temperature = 7.27
# Iteration 97: Best Fitness = 99.20, Temperature = 6.91
# Iteration 98: Best Fitness = 99.20, Temperature = 6.56
# Iteration 99: Best Fitness = 99.20, Temperature = 6.23
# Iteration 100: Best Fitness = 99.20, Temperature = 5.92
# Iteration 101: Best Fitness = 99.20, Temperature = 5.62
# Iteration 102: Best Fitness = 99.20, Temperature = 5.34
# Iteration 103: Best Fitness = 99.20, Temperature = 5.08
# Iteration 104: Best Fitness = 99.20, Temperature = 4.82
# Iteration 105: Best Fitness = 99.20, Temperature = 4.58
# Iteration 106: Best Fitness = 99.20, Temperature = 4.35
# Iteration 107: Best Fitness = 99.20, Temperature = 4.13
# Iteration 108: Best Fitness = 99.20, Temperature = 3.93
# Iteration 109: Best Fitness = 99.20, Temperature = 3.73
# Iteration 110: Best Fitness = 99.20, Temperature = 3.54
# Iteration 111: Best Fitness = 99.20, Temperature = 3.37
# Iteration 112: Best Fitness = 99.20, Temperature = 3.20
# Iteration 113: Best Fitness = 99.20, Temperature = 3.04
# Iteration 114: Best Fitness = 99.20, Temperature = 2.89
# Iteration 115: Best Fitness = 99.20, Temperature = 2.74
# Iteration 116: Best Fitness = 99.20, Temperature = 2.61
# Iteration 117: Best Fitness = 99.20, Temperature = 2.48
# Iteration 118: Best Fitness = 99.20, Temperature = 2.35
# Iteration 119: Best Fitness = 99.20, Temperature = 2.23
# Iteration 120: Best Fitness = 99.20, Temperature = 2.12
# Iteration 121: Best Fitness = 99.20, Temperature = 2.02
# Iteration 122: Best Fitness = 99.20, Temperature = 1.92
# Iteration 123: Best Fitness = 99.20, Temperature = 1.82
# Iteration 124: Best Fitness = 99.20, Temperature = 1.73
# Iteration 125: Best Fitness = 99.20, Temperature = 1.64
# Iteration 126: Best Fitness = 99.20, Temperature = 1.56
# Iteration 127: Best Fitness = 99.20, Temperature = 1.48
# Iteration 128: Best Fitness = 99.20, Temperature = 1.41
# Iteration 129: Best Fitness = 99.20, Temperature = 1.34
# Iteration 130: Best Fitness = 99.20, Temperature = 1.27
# Iteration 131: Best Fitness = 99.20, Temperature = 1.21
# Iteration 132: Best Fitness = 99.20, Temperature = 1.15
# Iteration 133: Best Fitness = 99.20, Temperature = 1.09
# Iteration 134: Best Fitness = 99.20, Temperature = 1.04
# Iteration 135: Best Fitness = 99.20, Temperature = 0.98
# Iteration 136: Best Fitness = 99.20, Temperature = 0.93
# Iteration 137: Best Fitness = 99.20, Temperature = 0.89
# Iteration 138: Best Fitness = 99.20, Temperature = 0.84
# Iteration 139: Best Fitness = 99.20, Temperature = 0.80
# Iteration 140: Best Fitness = 99.20, Temperature = 0.76
# Iteration 141: Best Fitness = 99.20, Temperature = 0.72
# Iteration 142: Best Fitness = 99.20, Temperature = 0.69
# Iteration 143: Best Fitness = 99.20, Temperature = 0.65
# Iteration 144: Best Fitness = 99.20, Temperature = 0.62
# Iteration 145: Best Fitness = 99.20, Temperature = 0.59
# Iteration 146: Best Fitness = 99.20, Temperature = 0.56
# Iteration 147: Best Fitness = 99.20, Temperature = 0.53
# Iteration 148: Best Fitness = 99.20, Temperature = 0.50
# Iteration 149: Best Fitness = 99.20, Temperature = 0.48
# Iteration 150: Best Fitness = 99.20, Temperature = 0.46
# Iteration 151: Best Fitness = 99.20, Temperature = 0.43
# Iteration 152: Best Fitness = 99.20, Temperature = 0.41
# Iteration 153: Best Fitness = 99.20, Temperature = 0.39
# Iteration 154: Best Fitness = 99.20, Temperature = 0.37
# Iteration 155: Best Fitness = 99.20, Temperature = 0.35
# Iteration 156: Best Fitness = 99.20, Temperature = 0.33
# Iteration 157: Best Fitness = 99.20, Temperature = 0.32
# Iteration 158: Best Fitness = 99.20, Temperature = 0.30
# Iteration 159: Best Fitness = 99.20, Temperature = 0.29
# Iteration 160: Best Fitness = 99.20, Temperature = 0.27
# Iteration 161: Best Fitness = 99.20, Temperature = 0.26
# Iteration 162: Best Fitness = 99.20, Temperature = 0.25
# Iteration 163: Best Fitness = 99.20, Temperature = 0.23
# Iteration 164: Best Fitness = 99.20, Temperature = 0.22
# Iteration 165: Best Fitness = 99.20, Temperature = 0.21
# Iteration 166: Best Fitness = 99.20, Temperature = 0.20
# Iteration 167: Best Fitness = 99.20, Temperature = 0.19
# Iteration 168: Best Fitness = 99.20, Temperature = 0.18
# Iteration 169: Best Fitness = 99.20, Temperature = 0.17
# Iteration 170: Best Fitness = 99.20, Temperature = 0.16
# Iteration 171: Best Fitness = 99.20, Temperature = 0.16
# Iteration 172: Best Fitness = 99.20, Temperature = 0.15
# Iteration 173: Best Fitness = 99.20, Temperature = 0.14
# Iteration 174: Best Fitness = 99.20, Temperature = 0.13
# Iteration 175: Best Fitness = 99.20, Temperature = 0.13
# Iteration 176: Best Fitness = 99.20, Temperature = 0.12
# Iteration 177: Best Fitness = 99.20, Temperature = 0.11
# Iteration 178: Best Fitness = 99.20, Temperature = 0.11
# Iteration 179: Best Fitness = 99.20, Temperature = 0.10
# Iteration 180: Best Fitness = 99.20, Temperature = 0.10
# Iteration 181: Best Fitness = 99.20, Temperature = 0.09
# Iteration 182: Best Fitness = 99.20, Temperature = 0.09
# Iteration 183: Best Fitness = 99.20, Temperature = 0.08
# Iteration 184: Best Fitness = 99.20, Temperature = 0.08
# Iteration 185: Best Fitness = 99.20, Temperature = 0.08
# Iteration 186: Best Fitness = 99.20, Temperature = 0.07
# Iteration 187: Best Fitness = 99.20, Temperature = 0.07
# Iteration 188: Best Fitness = 99.20, Temperature = 0.06
# Iteration 189: Best Fitness = 99.20, Temperature = 0.06
# Iteration 190: Best Fitness = 99.20, Temperature = 0.06
# Iteration 191: Best Fitness = 99.20, Temperature = 0.06
# Iteration 192: Best Fitness = 99.20, Temperature = 0.05
# Iteration 193: Best Fitness = 99.20, Temperature = 0.05
# Iteration 194: Best Fitness = 99.20, Temperature = 0.05
# Iteration 195: Best Fitness = 99.20, Temperature = 0.05
# Iteration 196: Best Fitness = 99.20, Temperature = 0.04
# Iteration 197: Best Fitness = 99.20, Temperature = 0.04
# Iteration 198: Best Fitness = 99.20, Temperature = 0.04
# Iteration 199: Best Fitness = 99.20, Temperature = 0.04
# Iteration 200: Best Fitness = 99.20, Temperature = 0.04
# Iteration 201: Best Fitness = 99.20, Temperature = 0.03
# Iteration 202: Best Fitness = 99.20, Temperature = 0.03
# Iteration 203: Best Fitness = 99.20, Temperature = 0.03
# Iteration 204: Best Fitness = 99.20, Temperature = 0.03
# Iteration 205: Best Fitness = 99.20, Temperature = 0.03
# Iteration 206: Best Fitness = 99.20, Temperature = 0.03
# Iteration 207: Best Fitness = 99.20, Temperature = 0.02
# Iteration 208: Best Fitness = 99.20, Temperature = 0.02
# Iteration 209: Best Fitness = 99.20, Temperature = 0.02
# Iteration 210: Best Fitness = 99.20, Temperature = 0.02
# Iteration 211: Best Fitness = 99.20, Temperature = 0.02
# Iteration 212: Best Fitness = 99.20, Temperature = 0.02
# Iteration 213: Best Fitness = 99.20, Temperature = 0.02
# Iteration 214: Best Fitness = 99.20, Temperature = 0.02
# Iteration 215: Best Fitness = 99.20, Temperature = 0.02
# Iteration 216: Best Fitness = 99.20, Temperature = 0.02
# Iteration 217: Best Fitness = 99.20, Temperature = 0.01
# Iteration 218: Best Fitness = 99.20, Temperature = 0.01
# Iteration 219: Best Fitness = 99.20, Temperature = 0.01
# Iteration 220: Best Fitness = 99.20, Temperature = 0.01
# Iteration 221: Best Fitness = 99.20, Temperature = 0.01
# Iteration 222: Best Fitness = 99.20, Temperature = 0.01
# Iteration 223: Best Fitness = 99.20, Temperature = 0.01
# Iteration 224: Best Fitness = 99.20, Temperature = 0.01
# Iteration 225: Best Fitness = 99.20, Temperature = 0.01
# Iteration 226: Best Fitness = 99.20, Temperature = 0.01
# Iteration 227: Best Fitness = 99.20, Temperature = 0.01
# Iteration 228: Best Fitness = 99.20, Temperature = 0.01
# Iteration 229: Best Fitness = 99.20, Temperature = 0.01
# Iteration 230: Best Fitness = 99.20, Temperature = 0.01
# Iteration 231: Best Fitness = 99.20, Temperature = 0.01
# Iteration 232: Best Fitness = 99.20, Temperature = 0.01
# Iteration 233: Best Fitness = 99.20, Temperature = 0.01
# Iteration 234: Best Fitness = 99.20, Temperature = 0.01
# Iteration 235: Best Fitness = 99.20, Temperature = 0.01
# Iteration 236: Best Fitness = 99.20, Temperature = 0.01
# Iteration 237: Best Fitness = 99.20, Temperature = 0.01
# Iteration 238: Best Fitness = 99.20, Temperature = 0.00
# Iteration 239: Best Fitness = 99.20, Temperature = 0.00
# Iteration 240: Best Fitness = 99.20, Temperature = 0.00
# Iteration 241: Best Fitness = 99.20, Temperature = 0.00
# Iteration 242: Best Fitness = 99.20, Temperature = 0.00
# Iteration 243: Best Fitness = 99.20, Temperature = 0.00
# Iteration 244: Best Fitness = 99.20, Temperature = 0.00
# Iteration 245: Best Fitness = 99.20, Temperature = 0.00
# Iteration 246: Best Fitness = 99.20, Temperature = 0.00
# Iteration 247: Best Fitness = 99.20, Temperature = 0.00
# Iteration 248: Best Fitness = 99.20, Temperature = 0.00
# Iteration 249: Best Fitness = 99.20, Temperature = 0.00
# Iteration 250: Best Fitness = 99.20, Temperature = 0.00
# Iteration 251: Best Fitness = 99.20, Temperature = 0.00
# Iteration 252: Best Fitness = 99.20, Temperature = 0.00
# Iteration 253: Best Fitness = 99.20, Temperature = 0.00
# Iteration 254: Best Fitness = 99.20, Temperature = 0.00
# Iteration 255: Best Fitness = 99.20, Temperature = 0.00
# Iteration 256: Best Fitness = 99.20, Temperature = 0.00
# Iteration 257: Best Fitness = 99.20, Temperature = 0.00
# Iteration 258: Best Fitness = 99.20, Temperature = 0.00
# Iteration 259: Best Fitness = 99.20, Temperature = 0.00
# Iteration 260: Best Fitness = 99.20, Temperature = 0.00
# Iteration 261: Best Fitness = 99.20, Temperature = 0.00
# Iteration 262: Best Fitness = 99.20, Temperature = 0.00
# Iteration 263: Best Fitness = 99.20, Temperature = 0.00
# Iteration 264: Best Fitness = 99.20, Temperature = 0.00
# Iteration 265: Best Fitness = 99.20, Temperature = 0.00
# Iteration 266: Best Fitness = 99.20, Temperature = 0.00
# Iteration 267: Best Fitness = 99.20, Temperature = 0.00
# Iteration 268: Best Fitness = 99.20, Temperature = 0.00
# Iteration 269: Best Fitness = 99.20, Temperature = 0.00
# Iteration 270: Best Fitness = 99.20, Temperature = 0.00
# Iteration 271: Best Fitness = 99.20, Temperature = 0.00
# Iteration 272: Best Fitness = 99.20, Temperature = 0.00
# Iteration 273: Best Fitness = 99.20, Temperature = 0.00
# Iteration 274: Best Fitness = 99.20, Temperature = 0.00
# Iteration 275: Best Fitness = 99.20, Temperature = 0.00
# Iteration 276: Best Fitness = 99.20, Temperature = 0.00
# Iteration 277: Best Fitness = 99.20, Temperature = 0.00
# Iteration 278: Best Fitness = 99.20, Temperature = 0.00
# Iteration 279: Best Fitness = 99.20, Temperature = 0.00
# Iteration 280: Best Fitness = 99.20, Temperature = 0.00
# Iteration 281: Best Fitness = 99.20, Temperature = 0.00
# Iteration 282: Best Fitness = 99.20, Temperature = 0.00
# Iteration 283: Best Fitness = 99.20, Temperature = 0.00
# Iteration 284: Best Fitness = 99.20, Temperature = 0.00
# Iteration 285: Best Fitness = 99.20, Temperature = 0.00
# Iteration 286: Best Fitness = 99.20, Temperature = 0.00
# Iteration 287: Best Fitness = 99.20, Temperature = 0.00
# Iteration 288: Best Fitness = 99.20, Temperature = 0.00
# Iteration 289: Best Fitness = 99.20, Temperature = 0.00
# Iteration 290: Best Fitness = 99.20, Temperature = 0.00
# Iteration 291: Best Fitness = 99.20, Temperature = 0.00
# Iteration 292: Best Fitness = 99.20, Temperature = 0.00
# Iteration 293: Best Fitness = 99.20, Temperature = 0.00
# Iteration 294: Best Fitness = 99.20, Temperature = 0.00
# Iteration 295: Best Fitness = 99.20, Temperature = 0.00
# Iteration 296: Best Fitness = 99.20, Temperature = 0.00
# Iteration 297: Best Fitness = 99.20, Temperature = 0.00
# Iteration 298: Best Fitness = 99.20, Temperature = 0.00
# Iteration 299: Best Fitness = 99.20, Temperature = 0.00
# Iteration 300: Best Fitness = 99.20, Temperature = 0.00
# Iteration 301: Best Fitness = 99.20, Temperature = 0.00
# Iteration 302: Best Fitness = 99.20, Temperature = 0.00
# Iteration 303: Best Fitness = 99.20, Temperature = 0.00
# Iteration 304: Best Fitness = 99.20, Temperature = 0.00
# Iteration 305: Best Fitness = 99.20, Temperature = 0.00
# Iteration 306: Best Fitness = 99.20, Temperature = 0.00
# Iteration 307: Best Fitness = 99.20, Temperature = 0.00
# Iteration 308: Best Fitness = 99.20, Temperature = 0.00
# Iteration 309: Best Fitness = 99.20, Temperature = 0.00
# Iteration 310: Best Fitness = 99.20, Temperature = 0.00
# Iteration 311: Best Fitness = 99.20, Temperature = 0.00
# Iteration 312: Best Fitness = 99.20, Temperature = 0.00
# Iteration 313: Best Fitness = 99.20, Temperature = 0.00
# Iteration 314: Best Fitness = 99.20, Temperature = 0.00
# Iteration 315: Best Fitness = 99.20, Temperature = 0.00
# Iteration 316: Best Fitness = 99.20, Temperature = 0.00
# Iteration 317: Best Fitness = 99.20, Temperature = 0.00
# Iteration 318: Best Fitness = 99.20, Temperature = 0.00
# Iteration 319: Best Fitness = 99.20, Temperature = 0.00
# Iteration 320: Best Fitness = 99.20, Temperature = 0.00
# Iteration 321: Best Fitness = 99.20, Temperature = 0.00
# Iteration 322: Best Fitness = 99.20, Temperature = 0.00
# Iteration 323: Best Fitness = 99.20, Temperature = 0.00
# Iteration 324: Best Fitness = 99.20, Temperature = 0.00
# Iteration 325: Best Fitness = 99.20, Temperature = 0.00
# Iteration 326: Best Fitness = 99.20, Temperature = 0.00
# Iteration 327: Best Fitness = 99.20, Temperature = 0.00
# Iteration 328: Best Fitness = 99.20, Temperature = 0.00
# Iteration 329: Best Fitness = 99.20, Temperature = 0.00
# Iteration 330: Best Fitness = 99.20, Temperature = 0.00
# Iteration 331: Best Fitness = 99.20, Temperature = 0.00
# Iteration 332: Best Fitness = 99.20, Temperature = 0.00
# Iteration 333: Best Fitness = 99.20, Temperature = 0.00
# Iteration 334: Best Fitness = 99.20, Temperature = 0.00
# Iteration 335: Best Fitness = 99.20, Temperature = 0.00
# Iteration 336: Best Fitness = 99.20, Temperature = 0.00
# Iteration 337: Best Fitness = 99.20, Temperature = 0.00
# Iteration 338: Best Fitness = 99.20, Temperature = 0.00
# Iteration 339: Best Fitness = 99.20, Temperature = 0.00
# Iteration 340: Best Fitness = 99.20, Temperature = 0.00
# Iteration 341: Best Fitness = 99.20, Temperature = 0.00
# Iteration 342: Best Fitness = 99.20, Temperature = 0.00
# Iteration 343: Best Fitness = 99.20, Temperature = 0.00
# Iteration 344: Best Fitness = 99.20, Temperature = 0.00
# Iteration 345: Best Fitness = 99.20, Temperature = 0.00
# Iteration 346: Best Fitness = 99.20, Temperature = 0.00
# Iteration 347: Best Fitness = 99.20, Temperature = 0.00
# Iteration 348: Best Fitness = 99.20, Temperature = 0.00
# Iteration 349: Best Fitness = 99.20, Temperature = 0.00
# Iteration 350: Best Fitness = 99.20, Temperature = 0.00
# Iteration 351: Best Fitness = 99.20, Temperature = 0.00
# Iteration 352: Best Fitness = 99.20, Temperature = 0.00
# Iteration 353: Best Fitness = 99.20, Temperature = 0.00
# Iteration 354: Best Fitness = 99.20, Temperature = 0.00
# Iteration 355: Best Fitness = 99.20, Temperature = 0.00
# Iteration 356: Best Fitness = 99.20, Temperature = 0.00
# Iteration 357: Best Fitness = 99.20, Temperature = 0.00
# Iteration 358: Best Fitness = 99.20, Temperature = 0.00
# Iteration 359: Best Fitness = 99.20, Temperature = 0.00
# Iteration 360: Best Fitness = 99.20, Temperature = 0.00
#
# Best solution using Simulated Annealing: ['Wheat', 'Spring', 'Phosphorus', 'Insecticide', 'High', 'Medium', 'Organic'] with Fitness: 99.20
